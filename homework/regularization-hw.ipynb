# %% [markdown]
# # Regularization (9 pts)

# %% [markdown]
# ---
# ### Collaborators
# You MUST include a bulleted list with the full names of everyone you collaborated with on this assignment.
# - Jane Doe
# - John Doe

# %% [markdown]
# ---
# The questions below refer to the dataset of cortical expression levels for 77 proteins in mice (`Data_Cortex_Nuclear.csv`). Your goal is to generate a model that describes the expression of BAD based on the expression profile of all other proteins.

# %%
import pandas as pd
df = pd.read_csv("data/Data_Cortex_Nuclear.csv")
proteins = df.loc[:,'DYRK1A_N':'CaNA_N']
proteins = proteins.fillna(proteins.mean())
proteins
# Out:
#       DYRK1A_N   ITSN1_N    BDNF_N     NR1_N    NR2A_N    pAKT_N   pBRAF_N  \
# 0     0.503644  0.747193  0.430175  2.816329  5.990152  0.218830  0.177565
# 1     0.514617  0.689064  0.411770  2.789514  5.685038  0.211636  0.172817
# 2     0.509183  0.730247  0.418309  2.687201  5.622059  0.209011  0.175722
# 3     0.442107  0.617076  0.358626  2.466947  4.979503  0.222886  0.176463
# 4     0.434940  0.617430  0.358802  2.365785  4.718679  0.213106  0.173627
# ...        ...       ...       ...       ...       ...       ...       ...
# 1075  0.254860  0.463591  0.254860  2.092082  2.600035  0.211736  0.171262
# 1076  0.272198  0.474163  0.251638  2.161390  2.801492  0.251274  0.182496
# 1077  0.228700  0.395179  0.234118  1.733184  2.220852  0.220665  0.161435
# 1078  0.221242  0.412894  0.243974  1.876347  2.384088  0.208897  0.173623
# 1079  0.302626  0.461059  0.256564  2.092790  2.594348  0.251001  0.191811
#
# ...

# %% [markdown]
# ---
# 1. (3 pts) From the `proteins` dataframe above, extract everything except `BAD_N` as your features and extract only the `BAD_N` column as your target. Then randomly shuffle the rows of your features and target.

# %% [markdown]
# ---
# 2. (3 pts) Use a grid search with 5-fold cross validation to find the optimal Lasso regression model that describes the expression of BAD based on the expression profile of all other proteins. *Hint: search for values of alpha in the vicinity of $10^{-6}$*.

# %% [markdown]
# ---
# 3. (3 pts) Identify which proteins were not very informative for predicting BAD expression levels.
